# %% [markdown]
#  # KHE Registration Time vs. Attendance

# %%
import attendance

years = [
    "./cleaned/khe16/apps.csv",
    "./cleaned/khe17/apps.csv",
    "./cleaned/khe18/apps.csv"
]

# %%
from attendance import plotAttendeesByAppTime

years = [
    "./cleaned/khe16/apps.csv",
    "./cleaned/khe17/apps.csv",
    "./cleaned/khe18/apps.csv"
]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-325b20cdf653> in <module>
#       1 #%%
# ----> 2 from attendance import plotAttendeesByAppTime
#       3
#       4 years = [
#       5     "./cleaned/khe16/apps.csv",
#
# ImportError: cannot import name 'plotAttendeesByAppTime' from 'attendance' (/home/alex/khe/data/attendance.py)

# %% [markdown]
#  # KHE Registration Time vs. Attendance

# %%
import attendance

years = [
    "./cleaned/khe16/apps.csv",
    "./cleaned/khe17/apps.csv",
    "./cleaned/khe18/apps.csv"
]

# %%
i = 0
attendance.plotAttendeesByAppTime(years[i])
# Out:
# /opt/anaconda/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# []

# %%
i = 1
attendance.plotAttendeesByAppTime(years[i])
# Out:
# []

# %%
i = 2
attendance.plotAttendeesByAppTime(years[i])
# Out:
# []
